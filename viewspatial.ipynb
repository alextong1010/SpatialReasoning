# %%
import json
from PIL import Image
from IPython.display import display
DATASET_PATH = "/net/holy-isilon/ifs/rc_labs/ydu_lab/alex"
RESULTS_FILE = "/n/home08/atong/projects/SpatialReasoning/results/view-spatial/qwen3vl_8b_instruct_free-form_temp.json"
with open(RESULTS_FILE) as f:
    data = json.load(f)
acc = data["accuracy"]
nc = data["num_correct"]
nt = data["num_total"]
print("Accuracy: {:.3f} ({}/{})".format(acc, nc, nt))
idx = 5
item = data["items"][idx]
image_path = DATASET_PATH + "/" + item["image_path"][0]
img = Image.open(image_path).convert("RGB")
display(img)
print("Prompt: " + item["prompt"])
print("GT Answer: " + item["gt_answer"])
print("Extracted: " + str(item["extracted"]))
print("Correct: " + str(item["correct"]))
print("\nResponse:\n" + item["response"])
# Out:
# Accuracy: 0.367 (309/842)
# <PIL.Image.Image image mode=RGB size=640x427 at 0x14ABB604C810>
# Prompt: Question: From the perspective of the man wearing the red hat, where is the person who is flying positioned?
# Choices:
# A. front
# B. back-right
# C. right
# D. back-left
# GT Answer: A. front
# Extracted: C
# Correct: False
#
# Response:
# C. right
